# %% [markdown]
# # Term Table

# %% [markdown]
# Display all terms of a specified indenture in one table

# %%
import sqlite3
import pandas as pd
import numpy as np
import string
from collections import defaultdict

# Establish the connection to database
sql_path = 'database.sqlite'
conn = sqlite3.connect(sql_path)
c = conn.cursor()

# %%
# Display settings
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('max_colwidth',500)

# %%
def definition_table(indenture_name, columns):    
    c.execute("select * FROM DEFINITION")
    all_info = c.fetchall()
    df = pd.DataFrame(all_info, columns=['Indentures', 'Term', 'Text'])
    term_list = df[df['Indentures']==indenture_name]['Term']
    
    # create the final dictionary
    dic = defaultdict(lambda : [])
    for term in term_list:
        if term[0] not in string.ascii_uppercase[:26].join(string.ascii_lowercase[:26]):
            dic['#'].append(term)
        else:
            dic[term[0].upper()].append(term)
            
    # create the final dataframe
    df = pd.DataFrame()
    for key,values in dic.items():
        if values:
            length = len(values) // columns
            rest_col = columns - len(values) % columns
            for i in range(length):
                df = df.append(pd.DataFrame(values[i*columns:(i+1)*columns], columns=[key]).T)
            if rest_col!=columns:
                df = df.append(pd.DataFrame(np.pad(values[(length)*columns:], (0,rest_col), 
                                              mode='constant', constant_values='-'),columns=[key]).T)
    df.index.name = 'Capital'
    return df

# %%
indenture_name = 'TEL133.20170810.dce07916-3ca5-2704-db92-fcfd7bbd6f53.5d35d0d4f9a56c3750c8880591dcb580.pdf'

# %%
print(indenture_name)
definition_table(indenture_name, columns=9)
# Out:
# TEL133.20170810.dce07916-3ca5-2704-db92-fcfd7bbd6f53.5d35d0d4f9a56c3750c8880591dcb580.pdf
#                                        0  \
# Capital
# #                         25% Limitation
# A                    Accountants’ Report
# A                         Affected Class
# A                                 Assets
# B                                Balance
# B                Bridge Financing Period
# C                             Caa Excess
# C                  Certificated Security
# C                          Class C Notes
# C            Class Scenario Default Rate
# C            Collateral Principal Amount
# C                 Corporate Trust Office
# C                              Custodian
# D                                Default
# D                               Due Date
# U                                  U.S.$
# E                         Effective Date
# E         Excel Default Model Input File
# F                                  FATCA
# F               Floating Rate Obligation
# G                                   GAAP
# H                        Hedge Agreement
# I                                 IAI/QP
# I         Interest Collection Subaccount
# I                 Investment Company Act
# J                           Junior Class
# K                       Key Person Event
# L                   LC Commitment Amount
# M                   Maintenance Covenant
# M                 Mezzanine Bridge Notes
# M        Moody’s Non-Senior Secured Loan
# N                        Non-Call Period
# O                                Obligor
# O                         Other Plan Law
# P                       Pari Passu Class
# P                        Permitted Liens
# P                         Priority Class
# Q                                 QIB/QP
# R                        Ramp-Up Account
# R                       Refinancing Date
# R                           Regulation S
# R                    Responsible Officer
# S                                    S&P
# S                          Sale Proceeds
# S                        Secured Parties
# S                    Senior Secured Loan
# S                     Subordinated Notes
# T                   Target Portfolio Par
# T                  Transaction Documents
# V                           Volcker Rule
# W                  Weighted Average Life
#
#                                              1  \
# Capital
# #                                            -
# A                                     Accounts
# A                                Agent Members
# A                    Assumed Reinvestment Rate
# B                                         Bank
# B                                 Business Day
# C                 Caa Excess Adjustment Amount
# C               Certificated Subordinated Note
# C                              Class C-R Notes
# C        Class X Principal Amortization Amount
# C                      Collateral Quality Test
# C                               Coverage Tests
# C                                            -
# D                          Deferrable Security
# D                                            -
# U                      Uncertificated Security
# E             Effective Date Moody’s Condition
# E                            Excepted Property
# F                             FATCA Compliance
# F                                            -
# G                                 Global Notes
# H                           Hedge Counterparty
# I                          Incurrence Covenant
# I                      Interest Coverage Ratio
# I                          Investment Criteria
# J                                            -
# K                       Knowledgeable Employee
# L             Letter of Credit Reserve Account
# M                                     Majority
# M                 Minimum Floating Spread Test
# M                      Moody’s Ramp-Up Failure
# N                   Non-Permitted ERISA Holder
# O                                        Offer
# O             Overcollateralization Ratio Test
# P                           Partial Redemption
# P                              Permitted Offer
# P                         Priority of Payments
# Q                      Qualified Broker/Dealer
# R               Rating Confirmation Redemption
# R                            Refinancing Notes
# R             Regulation S Global Secured Note
# R                    Restricted Trading Period
# S                              S&P CDO Monitor
# S           Schedule of Collateral Obligations
# S         Securities Account Control Agreement
# S                           Small Obligor Loan
# S                     Subsequent Delivery Date
# T               Target Portfolio Par Condition
# T                          Transaction Parties
# V                                            -
# W                   Weighted Average Life Test
#
#                                               2  \
# Capital
# #                                             -
# A                                Act of Holders
# A                Aggregate Excess Funded Spread
# A                          Authenticating Agent
# B                           Bankruptcy Exchange
# B                                             -
# C                             Calculation Agent
# C                                         Class
# C                        Class D Coverage Tests
# C                 Clearing Corporation Security
# C             Collateral Servicer Incentive Fee
# C                              Credit Agreement
# C                                             -
# D                            Deferring Security
# D                                             -
# U                         Underlying Instrument
# E                         Effective Date Report
# E                                  Exchange Act
# F                         Federal Reserve Board
# F                                             -
# G                      Global Subordinated Note
# H         Hedge Counterparty Collateral Account
# I                                     Indenture
# I                        Interest Coverage Test
# I          Investment Criteria Adjusted Balance
# J                                             -
# K                                             -
# L                                         LIBOR
# M                             Make-Whole Spread
# M                                         Money
# M                                Moody’s Rating
# N                          Non-Permitted Holder
# O                            Offered Securities
# O                                             -
# P                       Partial Redemption Date
# P                                        Person
# P                                    Proceeding
# Q                 Qualified Institutional Buyer
# R           Rating Confirmation Redemption Date
# R                Refinancing Notes Closing Date
# R         Regulation S Global Subordinated Note
# R                      Revolver Funding Account
# S                          S&P CDO Monitor Test
# S                        Scheduled Distribution
# S                                Securities Act
# S                            Special Redemption
# S                        Substitute Obligations
# T                                 Target Return
# T                                Transfer Agent
# V                                             -
# W        Weighted Average Moody’s Rating Factor
#
#                                                     3  \
# Capital
# #                                                   -
# A                  Additional Issuance Threshold Test
# A                             Aggregate Funded Spread
# A                                  Authorized Officer
# B                            Bankruptcy Exchange Test
# B                                                   -
# C                                                Cash
# C                                       Class A Notes
# C                                       Class D Notes
# C                                         Clearstream
# C                      Collateral Servicing Agreement
# C                            Credit Improved Criteria
# C                                                   -
# D              Delayed Drawdown Collateral Obligation
# D                                                   -
# U        Unpaid Class X Principal Amortization Amount
# E               Effective Date Specified Tested Items
# E                             Expense Reserve Account
# F                                    Fee Basis Amount
# F                                                   -
# G                                 Global Secured Note
# H                                              Holder
# I                               Independent Fiduciary
# I                         Interest Determination Date
# I                                      Issuer Request
# J                                                   -
# K                                                   -
# L                                                Loan
# M                                        Market Value
# M                                      Monthly Report
# M                            Moody’s Rating Condition
# N                                Note Interest Amount
# O                                            Offering
# O                                                   -
# P                              Participation Interest
# P                                   Portfolio Company
# P                                       Process Agent
# Q                                 Qualified Purchaser
# R                                         Record Date
# R                 Refinancing Notes Issuance Proceeds
# R                              Reinvestment Agreement
# R                     Revolving Collateral Obligation
# S                         S&P Industry Classification
# S                                    Second Lien Loan
# S                             Securities Intermediary
# S                           Special Redemption Amount
# S                                    Successor Entity
# T                                                 Tax
# T                                       Trust Officer
# V                                                   -
# W              Weighted Average Moody’s Recovery Rate
#
#                                                                   4  \
# Capital
# #                                                                 -
# A        Additional Subordinated Collateral Servicing Fee Condition
# A                                      Aggregate Outstanding Amount
# A                                                                 -
# B                                Bankruptcy Subordination Agreement
# B                                                                 -
# C                                                        CCC Excess
# C                                                   Class A-R Notes
# C                                                   Class D-R Notes
# C                                                      Closing Date
# C                                          Collateral Servicing Fee
# C                                        Credit Improved Obligation
# C                                                                 -
# D                                                Determination Date
# D                                                                 -
# U                                           Unregistered Securities
# E                                               Eligible Loan Index
# E                                                                 -
# F                                                   Financial Asset
# F                                                                 -
# G                                                           Granted
# H                                                                 -
# I                                                 Information Agent
# I                                           Interest Diversion Test
# I                                                  Issuer’s Website
# J                                                                 -
# K                                                                 -
# L                                                        Loan Agent
# M                                                          Maturity
# M                                                           Moody’s
# M                                             Moody’s Rating Factor
# N                                                        Noteholder
# O                                                 Offering Circular
# O                                                                 -
# P                                                      Paying Agent
# P                           Post-Reinvestment Collateral Obligation
# P                                                Proposed Portfolio
# Q                                                                 -
# R                                                Recovery Rate Case
# R                                              Refinancing Proceeds
# R                                               Reinvestment Period
# R                                                         Rule 144A
# S                                                        S&P Matrix
# S                                                      Secured Bond
# S                                              Security Entitlement
# S                                           Special Redemption Date
# S                                                     Supermajority
# T                                                  Tax Jurisdiction
# T                                                           Trustee
# V                                                                 -
# W                       Weighted Average Moody’s Recovery Rate Test
#
#                                             5  \
# Capital
# #                                           -
# A        Adjusted Collateral Principal Amount
# A                 Aggregate Principal Balance
# A                                           -
# B                          Board of Directors
# B                                           -
# C                CCC Excess Adjustment Amount
# C                    Class A/B Coverage Tests
# C                  Class Default Differential
# C                                        Code
# C                          Collection Account
# C                        Credit Risk Criteria
# C                                           -
# D                   DIP Collateral Obligation
# D                                           -
# U                           Unsaleable Assets
# E                           Enforcement Event
# E                                           -
# F                        Financing Statements
# F                                           -
# G                             Group I Country
# H                                           -
# I                           Initial Purchaser
# I                               Interest Rate
# I                                           -
# J                                           -
# K                                           -
# L                          London Banking Day
# M                          Maturity Amendment
# M                    Moody’s Collateral Value
# M                     Moody’s Recovery Amount
# N                                       Notes
# O                                     Officer
# O                                           -
# P                             Payment Account
# P        Post-Reinvestment Principal Proceeds
# P                          Purchase Agreement
# Q                                           -
# R                           Recovery Rate Set
# R                   Refinancing Secured Notes
# R             Reinvestment Target Par Balance
# R               Rule 144A Global Secured Note
# S                           S&P Matrix Spread
# S                         Secured Noteholders
# S                         Selling Institution
# S                             Stated Maturity
# S                           Surrendered Notes
# T                              Tax Redemption
# T                                           -
# V                                           -
# W          Weighted Average S&P Recovery Rate
#
#                                                        6  \
# Capital
# #                                                      -
# A        Adjusted Weighted Average Moody’s Rating Factor
# A                              Aggregate Unfunded Spread
# A                                                      -
# B                                       Board Resolution
# B                                                      -
# C                                                    CEA
# C                                          Class B Notes
# C                                 Class E Coverage Tests
# C                                             Co-Issuers
# C                                      Collection Period
# C                                 Credit Risk Obligation
# C                                                      -
# D                                    Distribution Report
# D                                                      -
# U                                         Unsecured Loan
# E                                                  ERISA
# E                                                      -
# F                                                  Fitch
# F                                                      -
# G                                      Group III Country
# H                                                      -
# I                                         Initial Rating
# I                               Interest Reserve Account
# I                                                      -
# J                                                      -
# K                                                      -
# L                                  Long-Dated Obligation
# M                                       Measurement Date
# M                     Moody’s Default Probability Rating
# M                                  Moody’s Recovery Rate
# N                                                  NRSRO
# O                                   offshore transaction
# O                                                      -
# P                                           Payment Date
# P                                      Principal Balance
# P                                                      -
# Q                                                      -
# R                                        Redemption Date
# R                         Refinancing Subordinated Notes
# R                     Required Hedge Counterparty Rating
# R                     Rule 144A Global Subordinated Note
# S                        S&P Rating Confirmation Failure
# S                          Secured Note Payment Sequence
# S                                   Senior Bridge Lender
# S                                   Step-Down Obligation
# S                                     Synthetic Security
# T                                         Tax Subsidiary
# T                                                      -
# V                                                      -
# W                Weighted Average S&P Recovery Rate Test
#
#                                                  7  \
# Capital
# #                                                -
# A                       Administrative Expense Cap
# A                               Applicable Issuers
# A                                                -
# B                                             Bond
# B                                                -
# C                               Certificated Notes
# C                                  Class B-R Notes
# C                                    Class E Notes
# C              Collateral Administration Agreement
# C                         Confidential Information
# C                                Current Portfolio
# C                                                -
# D                                  Diversity Score
# D                                                -
# U                                      U.S. person
# E                                        Euroclear
# E                                                -
# F                                     Fitch Rating
# F                                                -
# G                                 Group IV Country
# H                                                -
# I                                       Instrument
# I                              Interim Report Date
# I                                                -
# J                                                -
# K                                                -
# L                                                -
# M                                   Merging Entity
# M                           Moody’s Derived Rating
# M        Moody’s Senior Secured Floating Rate Note
# N                              NRSRO Certification
# O                               Opinion of Counsel
# O                                                -
# P                                             PBGC
# P                  Principal Collection Subaccount
# P                                                -
# Q                                                -
# R                                  Reference Banks
# R                                       Registered
# R                 Required Interest Coverage Ratio
# R                            Rule 144A Information
# S                                S&P Recovery Rate
# S                                    Secured Notes
# S                  Senior Collateral Servicing Fee
# S                               Step-Up Obligation
# S                                                -
# T                                     Trading Plan
# T                                                -
# V                                                -
# W                                                -
#
#                                              8
# Capital
# #                                            -
# A                      Administrative Expenses
# A                Asset-Backed Commercial Paper
# A                                            -
# B                                  Bridge Loan
# B                                            -
# C                    Certificated Secured Note
# C                       Class C Coverage Tests
# C                              Class E-R Notes
# C                     Collateral Administrator
# C                            Controlling Class
# C                            Custodial Account
# C                                            -
# D                                    Domiciled
# D                                            -
# U                                            -
# E                             Event of Default
# E                                            -
# F                        Fixed Rate Obligation
# F                                            -
# G                                            -
# H                                            -
# I                      Interest Accrual Period
# I                      Internal Rate of Return
# I                                            -
# J                                            -
# K                                            -
# L                                            -
# M                      Memorandum and Articles
# M              Moody’s Industry Classification
# M                  Moody’s Senior Secured Loan
# N                                            -
# O                          Optional Redemption
# O                                            -
# P                Permitted Deferrable Security
# P          Principal Financed Accrued Interest
# P                                            -
# Q                                            -
# R                                  Refinancing
# R                Registered Investment Adviser
# R         Required Overcollateralization Ratio
# R                                   Rule 17g-5
# S                                         Sale
# S                          Secured Obligations
# S            Senior Secured Floating Rate Note
# S        Subordinated Collateral Servicing Fee
# S                                            -
# T                          Trading Plan Period
# T                                            -
# V                                            -
# W                                            -

# %% [markdown]
# # Search in SQL database

# %% [markdown]
# Search information in the pre-created SQL database

# %%
def sql_search(indenture, term):
    sqlite_file = 'database.sqlite'
    conn = sqlite3.connect(sqlite_file)
    c = conn.cursor()
    
    # search term in target indenture
    query1 = """
    SELECT definition
    FROM DEFINITION
    WHERE term = '%s' AND file_name = '%s' 
    """ %(term, indenture)
    c.execute(query1)
    target_text = c.fetchall()
    
    # search all terms in the database
    query2 = """
    SELECT file_name, definition
    FROM DEFINITION
    WHERE term = '%s' 
    """ %(term)
    c.execute(query2)
    all_info = c.fetchall()
    text_list = [x[1] for x in all_info]
    
    return target_text[0][0], text_list, all_info

# %%
# term = input()
# target_text, text_list, all_info = sql_search(indenture_name, term)
# target_text, text_list

# %% [markdown]
# # Similarity Table

# %% [markdown]
# Calculate similarity score by self-trained word vector with 100 dimensions and Word Mover's Distance algorithm

# %%
from Similarity import Similarity_score
from frequency_weight import word_freq_dict, sent_score, sql_freq, indenture_names, get_sent_score, color_df

# %%
# Input
search_indenture = 'TEL133.20170810.dce07916-3ca5-2704-db92-fcfd7bbd6f53.5d35d0d4f9a56c3750c8880591dcb580.pdf'
search_term = 'Authorized Officer'

# %%
# all_info include both target text and comparison text (indenture name + text)
target_text, all_text, all_info = sql_search(search_indenture, search_term)
model_path = './w2v_selftrained/w2v_100_sg.bin'

# Similarity Score
score = Similarity_score(target_text, all_text, model_path)
final_score = [round(x,4) for x in score.result()]

# Get sentences and corresponding scores
res = get_sent_score(search_term, all_text)

# %%
# Stack dataframe
df = pd.DataFrame({'Indenture': [indenture_names(x[0]) for x in all_info],
                   'Similarity_Score': final_score, 'Text': res[0], 'Sent_Score': res[1]})

df_target  = df[df['Indenture'] == indenture_names(search_indenture)]
df_comp = df[df['Indenture'] != indenture_names(search_indenture)]

# dataframe for the target term
df_target = df_target.set_index(['Indenture', 'Similarity_Score']).stack().str.split('##', expand=True).stack().unstack(-2)
df_target['Sent_Score'] = df_target['Sent_Score'].astype(float)

# dataframe for comparison terms
df_comp = df_comp.set_index(['Indenture', 'Similarity_Score']).stack().str.split('##', expand=True).stack().unstack(-2)
df_comp['Sent_Score'] = df_comp['Sent_Score'].astype(float)
df_comp = df_comp.sort_values(by=['Similarity_Score',  'Indenture'], ascending=False)

# %%
# Color coding for target text
df_target.style.apply(color_df,axis=1)
# Out:
# <style  type="text/css" >
#     #T_09aa7e5a_6c4e_11e9_a03f_f21898386f3brow0_col0 {
#             color:  #bfbf00;
#         }    #T_09aa7e5a_6c4e_11e9_a03f_f21898386f3brow1_col0 {
#             color:  #008000;
#         }    #T_09aa7e5a_6c4e_11e9_a03f_f21898386f3brow2_col0 {
#             color:  #008000;
#         }    #T_09aa7e5a_6c4e_11e9_a03f_f21898386f3brow3_col0 {
#             color:  #bfbf00;
#         }    #T_09aa7e5a_6c4e_11e9_a03f_f21898386f3brow4_col0 {
#             color:  #f00;
#         }    #T_09aa7e5a_6c4e_11e9_a03f_f21898386f3brow5_col0 {
#             color:  #bfbf00;
#         }</style>
# <table id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3b" >
# <thead>    <tr>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#         <th class="blank level0" ></th>
#         <th class="col_heading level0 col0" >Text</th>
#         <th class="col_heading level0 col1" >Sent_Score</th>
#     </tr>    <tr>
#         <th class="index_name level0" >Indenture</th>
#         <th class="index_name level1" >Similarity_Score</th>
#         <th class="index_name level2" ></th>
#         <th class="blank" ></th>
#         <th class="blank" ></th>
#     </tr></thead>
# <tbody>    <tr>
#         <th id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3blevel0_row0" class="row_heading level0 row0" rowspan=6>TEL133</th>
#         <th id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3blevel1_row0" class="row_heading level1 row0" rowspan=6>1.0</th>
#         <th id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3blevel2_row0" class="row_heading level2 row0" >0</th>
#         <td id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3brow0_col0" class="data row0 col0" >With respect to the Issuer or the Co-Issuer, any Officer orany other Person who is authorized to act for the Issuer or the Co-Issuer, as applicable, in mattersrelating to, and binding upon, the Issuer or the Co-Issuer.</td>
#         <td id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3brow0_col1" class="data row0 col1" >0.6</td>
#     </tr>    <tr>
#         <th id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3blevel2_row1" class="row_heading level2 row1" >1</th>
#         <td id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3brow1_col0" class="data row1 col0" >With respect to the Collateral Servicer,any Officer, employee, member or agent of the Collateral Servicer who is authorized to act forthe Collateral Servicer in matters relating to, and binding upon, the Collateral Servicer withrespect to the subject matter of the request, certificate or order in question.</td>
#         <td id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3brow1_col1" class="data row1 col1" >0.89</td>
#     </tr>    <tr>
#         <th id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3blevel2_row2" class="row_heading level2 row2" >2</th>
#         <td id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3brow2_col0" class="data row2 col0" >With respect to theCollateral Administrator, any Officer, employee, partner or agent of the Collateral Administratorwho is authorized to act for the Collateral Administrator in matters relating to, and binding upon,the Collateral Administrator with respect to the subject matter of the request, certificate or orderin question.</td>
#         <td id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3brow2_col1" class="data row2 col1" >1</td>
#     </tr>    <tr>
#         <th id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3blevel2_row3" class="row_heading level2 row3" >3</th>
#         <td id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3brow3_col0" class="data row3 col0" >With respect to the Trustee or any other bank or trust company acting as trustee ofan express trust or as custodian or the Loan Agent, a Trust Officer.</td>
#         <td id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3brow3_col1" class="data row3 col1" >0.42</td>
#     </tr>    <tr>
#         <th id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3blevel2_row4" class="row_heading level2 row4" >4</th>
#         <td id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3brow4_col0" class="data row4 col0" >With respect to anyAuthenticating Agent, any Officer of such Authenticating Agent who is authorized toauthenticate the Offered Securities and/or the Mezzanine Bridge Notes.</td>
#         <td id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3brow4_col1" class="data row4 col1" >0.29</td>
#     </tr>    <tr>
#         <th id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3blevel2_row5" class="row_heading level2 row5" >5</th>
#         <td id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3brow5_col0" class="data row5 col0" >Each party may receiveand accept a certification of the authority of any other party as conclusive evidence of theauthority of any person to act, and such certification may be considered as in full force and effectuntil receipt by such other party of written notice to the contrary</td>
#         <td id="T_09aa7e5a_6c4e_11e9_a03f_f21898386f3brow5_col1" class="data row5 col1" >0.42</td>
#     </tr></tbody>
# </table>

# %%
# Color coding for comparison text
df_comp.style.apply(color_df,axis=1)
# Out:
# <style  type="text/css" >
#     #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow0_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow1_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow2_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow3_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow4_col0 {
#             color:  #f00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow5_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow6_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow7_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow8_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow9_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow10_col0 {
#             color:  #f00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow11_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow12_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow13_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow14_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow15_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow16_col0 {
#             color:  #f00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow17_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow18_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow19_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow20_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow21_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow22_col0 {
#             color:  #f00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow23_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow24_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow25_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow26_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow27_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow28_col0 {
#             color:  #f00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow29_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow30_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow31_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow32_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow33_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow34_col0 {
#             color:  #f00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow35_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow36_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow37_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow38_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow39_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow40_col0 {
#             color:  #f00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow41_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow42_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow43_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow44_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow45_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow46_col0 {
#             color:  #f00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow47_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow48_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow49_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow50_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow51_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow52_col0 {
#             color:  #f00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow53_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow54_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow55_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow56_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow57_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow58_col0 {
#             color:  #f00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow59_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow60_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow61_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow62_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow63_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow64_col0 {
#             color:  #f00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow65_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow66_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow67_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow68_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow69_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow70_col0 {
#             color:  #f00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow71_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow72_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow73_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow74_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow75_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow76_col0 {
#             color:  #f00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow77_col0 {
#             color:  #bfbf00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow78_col0 {
#             color:  #f00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow79_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow80_col0 {
#             color:  #f00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow81_col0 {
#             color:  #f00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow82_col0 {
#             color:  #f00;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow83_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3brow84_col0 {
#             color:  #008000;
#         }    #T_0ae9529e_6c4e_11e9_b195_f21898386f3bro

# %% [markdown]
# # Highlight Difference

# %%
from diff_highlight import find_text, inline_diff

# %%
comp1_name = 'TEL133'
comp2_name = 'MIDOCC2'

# %%
comp1 = find_text(comp1_name, all_info)
comp2 = find_text(comp2_name, all_info)

from colored import fg, bg, attr, stylize
print ('%s Target text: %s' % (fg(1), attr(0)))
print(comp1,'\n')

# comp1 will be the banchmark
# comp2 is the comparison text
# return comp2 with highlight color
print ('%s Comparison text: %s' % (fg(1), attr(0)))
print(inline_diff(comp2, comp1))
# Out:
#  Target text:
# With respect to the Issuer or the Co-Issuer, any Officer orany other Person who is authorized to act for the Issuer or the Co-Issuer, as applicable, in mattersrelating to, and binding upon, the Issuer or the Co-Issuer. With respect to the Collateral Servicer,any Officer, employee, member or agent of the Collateral Servicer who is authorized to act forthe Collateral Servicer in matters relating to, and binding upon, the Collateral Servicer withrespect to the subject matter of the request, certificate or order in question. With respect to theCollateral Administrator, any Officer, employee, partner or agent of the Collateral Administratorwho is authorized to act for the Collateral Administrator in matters relating to, and binding upon,the Collateral Administrator with respect to the subject matter of the request, certificate or orderin question. With respect to the Trustee or any other bank or trust company acting as trustee ofan express trust or as custodian or the Loan Agent, a Trust Officer. With respect to anyAuthenticating Agent, any Officer of such Authenticating Agent who is authorized toauthenticate the Offered Securities and/or the Mezzanine Bridge Notes. Each party may receiveand accept a certification of the authority of any other party as conclusive evidence of theauthority of any person to act, and such certification may be considered as in full force and effectuntil receipt by such other party of written notice to the contrary
#
#  Comparison text:
# With respect to the Issuer or the Co-Issuer, any Officer or anyother Person who is authorized to act for the Issuer or the Co-Issuer, as applicable, in mattersrelating to, and binding upon, the Issuer or the Co-Issuer. With respect to the Portfolio Manager,any Officer, employee, member or agent of the Portfolio Manager who is authorized to act forthe Portfolio Manager in matters relating to, and binding upon, the Portfolio Manager withrespect to the subject matter of the request, certificate or order in question. With respect to theCollateral Administrator, any Officer, employee, partner or agent of the Collateral Administratorwho is authorized to act for the Collateral Administrator in matters relating to, and binding upon,the Collateral Administrator with respect to the subject matter of the request, certificate or orderin question. With respect to the Trustee or any other bank or trust company acting as trustee ofan express trust or as custodian, a Trust Officer. With respect to any Authenticating Agent, anyOfficer of such Authenticating Agent...... who is authorized to authenticate the Notes. Each party......may receive and accept a certification of the authority of any other party as conclusive evidenceof the authority of any person to act, and such certification may be considered as in full force andeffect until receipt by such other party of written notice to the contrary

# %%
# Close the database
conn.close()
