# %% [markdown]
# # Term Table

# %% [markdown]
# Display all terms of a specified indenture in one table

# %%
import sqlite3
import pandas as pd
import numpy as np
import string
from collections import defaultdict

def definition_table(sqlite_file, indenture_name, columns):    
    conn = sqlite3.connect(sqlite_file)
    c = conn.cursor()
    c.execute("select * FROM DEFINITION")
    all_info = c.fetchall()
    df = pd.DataFrame(all_info, columns=['Indentures', 'Term', 'Text'])
    term_list = df[df['Indentures']==indenture_name]['Term']
    
    # create the final dictionary
    dic = defaultdict(lambda : [])
    for term in term_list:
        if term[0] not in string.ascii_uppercase[:26].join(string.ascii_lowercase[:26]):
            dic['#'].append(term)
        else:
            dic[term[0].upper()].append(term)
            
    # create the final dataframe
    df = pd.DataFrame()
    for key,values in dic.items():
        if values:
            length = len(values) // columns
            rest_col = columns - len(values) % columns
            for i in range(length):
                df = df.append(pd.DataFrame(values[i*columns:(i+1)*columns], columns=[key]).T)
            if rest_col!=columns:
                df = df.append(pd.DataFrame(np.pad(values[(length)*columns:], (0,rest_col), 
                                              mode='constant', constant_values='-'),columns=[key]).T)
    df.index.name = 'Capital'
    return df

# %%
pd.set_option('display.max_columns', None)
pd.set_option('display.max_rows', None)
pd.set_option('max_colwidth',200)

# %%
indenture_name = 'TEL133.20170810.dce07916-3ca5-2704-db92-fcfd7bbd6f53.5d35d0d4f9a56c3750c8880591dcb580.pdf'
sql_path = 'database.sqlite'

# %%
print(indenture_name)
definition_table(sql_path, indenture_name, columns=9)
# Out:
# TEL133.20170810.dce07916-3ca5-2704-db92-fcfd7bbd6f53.5d35d0d4f9a56c3750c8880591dcb580.pdf
#                                        0  \
# Capital
# #                         25% Limitation
# A                    Accountants’ Report
# A                         Affected Class
# A                                 Assets
# B                                Balance
# B                Bridge Financing Period
# C                             Caa Excess
# C                  Certificated Security
# C                          Class C Notes
# C            Class Scenario Default Rate
# C            Collateral Principal Amount
# C                 Corporate Trust Office
# C                              Custodian
# D                                Default
# D                               Due Date
# U                                  U.S.$
# E                         Effective Date
# E         Excel Default Model Input File
# F                                  FATCA
# F               Floating Rate Obligation
# G                                   GAAP
# H                        Hedge Agreement
# I                                 IAI/QP
# I         Interest Collection Subaccount
# I                 Investment Company Act
# J                           Junior Class
# K                       Key Person Event
# L                   LC Commitment Amount
# M                   Maintenance Covenant
# M                 Mezzanine Bridge Notes
# M        Moody’s Non-Senior Secured Loan
# N                        Non-Call Period
# O                                Obligor
# O                         Other Plan Law
# P                       Pari Passu Class
# P                        Permitted Liens
# P                         Priority Class
# Q                                 QIB/QP
# R                        Ramp-Up Account
# R                       Refinancing Date
# R                           Regulation S
# R                    Responsible Officer
# S                                    S&P
# S                          Sale Proceeds
# S                        Secured Parties
# S                    Senior Secured Loan
# S                     Subordinated Notes
# T                   Target Portfolio Par
# T                  Transaction Documents
# V                           Volcker Rule
# W                  Weighted Average Life
#
#                                              1  \
# Capital
# #                                            -
# A                                     Accounts
# A                                Agent Members
# A                    Assumed Reinvestment Rate
# B                                         Bank
# B                                 Business Day
# C                 Caa Excess Adjustment Amount
# C               Certificated Subordinated Note
# C                              Class C-R Notes
# C        Class X Principal Amortization Amount
# C                      Collateral Quality Test
# C                               Coverage Tests
# C                                            -
# D                          Deferrable Security
# D                                            -
# U                      Uncertificated Security
# E             Effective Date Moody’s Condition
# E                            Excepted Property
# F                             FATCA Compliance
# F                                            -
# G                                 Global Notes
# H                           Hedge Counterparty
# I                          Incurrence Covenant
# I                      Interest Coverage Ratio
# I                          Investment Criteria
# J                                            -
# K                       Knowledgeable Employee
# L             Letter of Credit Reserve Account
# M                                     Majority
# M                 Minimum Floating Spread Test
# M                      Moody’s Ramp-Up Failure
# N                   Non-Permitted ERISA Holder
# O                                        Offer
# O             Overcollateralization Ratio Test
# P                           Partial Redemption
# P                              Permitted Offer
# P                         Priority of Payments
# Q                      Qualified Broker/Dealer
# R               Rating Confirmation Redemption
# R                            Refinancing Notes
# R             Regulation S Global Secured Note
# R                    Restricted Trading Period
# S                              S&P CDO Monitor
# S           Schedule of Collateral Obligations
# S         Securities Account Control Agreement
# S                           Small Obligor Loan
# S                     Subsequent Delivery Date
# T               Target Portfolio Par Condition
# T                          Transaction Parties
# V                                            -
# W                   Weighted Average Life Test
#
#                                               2  \
# Capital
# #                                             -
# A                                Act of Holders
# A                Aggregate Excess Funded Spread
# A                          Authenticating Agent
# B                           Bankruptcy Exchange
# B                                             -
# C                             Calculation Agent
# C                                         Class
# C                        Class D Coverage Tests
# C                 Clearing Corporation Security
# C             Collateral Servicer Incentive Fee
# C                              Credit Agreement
# C                                             -
# D                            Deferring Security
# D                                             -
# U                         Underlying Instrument
# E                         Effective Date Report
# E                                  Exchange Act
# F                         Federal Reserve Board
# F                                             -
# G                      Global Subordinated Note
# H         Hedge Counterparty Collateral Account
# I                                     Indenture
# I                        Interest Coverage Test
# I          Investment Criteria Adjusted Balance
# J                                             -
# K                                             -
# L                                         LIBOR
# M                             Make-Whole Spread
# M                                         Money
# M                                Moody’s Rating
# N                          Non-Permitted Holder
# O                            Offered Securities
# O                                             -
# P                       Partial Redemption Date
# P                                        Person
# P                                    Proceeding
# Q                 Qualified Institutional Buyer
# R           Rating Confirmation Redemption Date
# R                Refinancing Notes Closing Date
# R         Regulation S Global Subordinated Note
# R                      Revolver Funding Account
# S                          S&P CDO Monitor Test
# S                        Scheduled Distribution
# S                                Securities Act
# S                            Special Redemption
# S                        Substitute Obligations
# T                                 Target Return
# T                                Transfer Agent
# V                                             -
# W        Weighted Average Moody’s Rating Factor
#
#                                                     3  \
# Capital
# #                                                   -
# A                  Additional Issuance Threshold Test
# A                             Aggregate Funded Spread
# A                                  Authorized Officer
# B                            Bankruptcy Exchange Test
# B                                                   -
# C                                                Cash
# C                                       Class A Notes
# C                                       Class D Notes
# C                                         Clearstream
# C                      Collateral Servicing Agreement
# C                            Credit Improved Criteria
# C                                                   -
# D              Delayed Drawdown Collateral Obligation
# D                                                   -
# U        Unpaid Class X Principal Amortization Amount
# E               Effective Date Specified Tested Items
# E                             Expense Reserve Account
# F                                    Fee Basis Amount
# F                                                   -
# G                                 Global Secured Note
# H                                              Holder
# I                               Independent Fiduciary
# I                         Interest Determination Date
# I                                      Issuer Request
# J                                                   -
# K                                                   -
# L                                                Loan
# M                                        Market Value
# M                                      Monthly Report
# M                            Moody’s Rating Condition
# N                                Note Interest Amount
# O                                            Offering
# O                                                   -
# P                              Participation Interest
# P                                   Portfolio Company
# P                                       Process Agent
# Q                                 Qualified Purchaser
# R                                         Record Date
# R                 Refinancing Notes Issuance Proceeds
# R                              Reinvestment Agreement
# R                     Revolving Collateral Obligation
# S                         S&P Industry Classification
# S                                    Second Lien Loan
# S                             Securities Intermediary
# S                           Special Redemption Amount
# S                                    Successor Entity
# T                                                 Tax
# T                                       Trust Officer
# V                                                   -
# W              Weighted Average Moody’s Recovery Rate
#
#                                                                   4  \
# Capital
# #                                                                 -
# A        Additional Subordinated Collateral Servicing Fee Condition
# A                                      Aggregate Outstanding Amount
# A                                                                 -
# B                                Bankruptcy Subordination Agreement
# B                                                                 -
# C                                                        CCC Excess
# C                                                   Class A-R Notes
# C                                                   Class D-R Notes
# C                                                      Closing Date
# C                                          Collateral Servicing Fee
# C                                        Credit Improved Obligation
# C                                                                 -
# D                                                Determination Date
# D                                                                 -
# U                                           Unregistered Securities
# E                                               Eligible Loan Index
# E                                                                 -
# F                                                   Financial Asset
# F                                                                 -
# G                                                           Granted
# H                                                                 -
# I                                                 Information Agent
# I                                           Interest Diversion Test
# I                                                  Issuer’s Website
# J                                                                 -
# K                                                                 -
# L                                                        Loan Agent
# M                                                          Maturity
# M                                                           Moody’s
# M                                             Moody’s Rating Factor
# N                                                        Noteholder
# O                                                 Offering Circular
# O                                                                 -
# P                                                      Paying Agent
# P                           Post-Reinvestment Collateral Obligation
# P                                                Proposed Portfolio
# Q                                                                 -
# R                                                Recovery Rate Case
# R                                              Refinancing Proceeds
# R                                               Reinvestment Period
# R                                                         Rule 144A
# S                                                        S&P Matrix
# S                                                      Secured Bond
# S                                              Security Entitlement
# S                                           Special Redemption Date
# S                                                     Supermajority
# T                                                  Tax Jurisdiction
# T                                                           Trustee
# V                                                                 -
# W                       Weighted Average Moody’s Recovery Rate Test
#
#                                             5  \
# Capital
# #                                           -
# A        Adjusted Collateral Principal Amount
# A                 Aggregate Principal Balance
# A                                           -
# B                          Board of Directors
# B                                           -
# C                CCC Excess Adjustment Amount
# C                    Class A/B Coverage Tests
# C                  Class Default Differential
# C                                        Code
# C                          Collection Account
# C                        Credit Risk Criteria
# C                                           -
# D                   DIP Collateral Obligation
# D                                           -
# U                           Unsaleable Assets
# E                           Enforcement Event
# E                                           -
# F                        Financing Statements
# F                                           -
# G                             Group I Country
# H                                           -
# I                           Initial Purchaser
# I                               Interest Rate
# I                                           -
# J                                           -
# K                                           -
# L                          London Banking Day
# M                          Maturity Amendment
# M                    Moody’s Collateral Value
# M                     Moody’s Recovery Amount
# N                                       Notes
# O                                     Officer
# O                                           -
# P                             Payment Account
# P        Post-Reinvestment Principal Proceeds
# P                          Purchase Agreement
# Q                                           -
# R                           Recovery Rate Set
# R                   Refinancing Secured Notes
# R             Reinvestment Target Par Balance
# R               Rule 144A Global Secured Note
# S                           S&P Matrix Spread
# S                         Secured Noteholders
# S                         Selling Institution
# S                             Stated Maturity
# S                           Surrendered Notes
# T                              Tax Redemption
# T                                           -
# V                                           -
# W          Weighted Average S&P Recovery Rate
#
#                                                        6  \
# Capital
# #                                                      -
# A        Adjusted Weighted Average Moody’s Rating Factor
# A                              Aggregate Unfunded Spread
# A                                                      -
# B                                       Board Resolution
# B                                                      -
# C                                                    CEA
# C                                          Class B Notes
# C                                 Class E Coverage Tests
# C                                             Co-Issuers
# C                                      Collection Period
# C                                 Credit Risk Obligation
# C                                                      -
# D                                    Distribution Report
# D                                                      -
# U                                         Unsecured Loan
# E                                                  ERISA
# E                                                      -
# F                                                  Fitch
# F                                                      -
# G                                      Group III Country
# H                                                      -
# I                                         Initial Rating
# I                               Interest Reserve Account
# I                                                      -
# J                                                      -
# K                                                      -
# L                                  Long-Dated Obligation
# M                                       Measurement Date
# M                     Moody’s Default Probability Rating
# M                                  Moody’s Recovery Rate
# N                                                  NRSRO
# O                                   offshore transaction
# O                                                      -
# P                                           Payment Date
# P                                      Principal Balance
# P                                                      -
# Q                                                      -
# R                                        Redemption Date
# R                         Refinancing Subordinated Notes
# R                     Required Hedge Counterparty Rating
# R                     Rule 144A Global Subordinated Note
# S                        S&P Rating Confirmation Failure
# S                          Secured Note Payment Sequence
# S                                   Senior Bridge Lender
# S                                   Step-Down Obligation
# S                                     Synthetic Security
# T                                         Tax Subsidiary
# T                                                      -
# V                                                      -
# W                Weighted Average S&P Recovery Rate Test
#
#                                                  7  \
# Capital
# #                                                -
# A                       Administrative Expense Cap
# A                               Applicable Issuers
# A                                                -
# B                                             Bond
# B                                                -
# C                               Certificated Notes
# C                                  Class B-R Notes
# C                                    Class E Notes
# C              Collateral Administration Agreement
# C                         Confidential Information
# C                                Current Portfolio
# C                                                -
# D                                  Diversity Score
# D                                                -
# U                                      U.S. person
# E                                        Euroclear
# E                                                -
# F                                     Fitch Rating
# F                                                -
# G                                 Group IV Country
# H                                                -
# I                                       Instrument
# I                              Interim Report Date
# I                                                -
# J                                                -
# K                                                -
# L                                                -
# M                                   Merging Entity
# M                           Moody’s Derived Rating
# M        Moody’s Senior Secured Floating Rate Note
# N                              NRSRO Certification
# O                               Opinion of Counsel
# O                                                -
# P                                             PBGC
# P                  Principal Collection Subaccount
# P                                                -
# Q                                                -
# R                                  Reference Banks
# R                                       Registered
# R                 Required Interest Coverage Ratio
# R                            Rule 144A Information
# S                                S&P Recovery Rate
# S                                    Secured Notes
# S                  Senior Collateral Servicing Fee
# S                               Step-Up Obligation
# S                                                -
# T                                     Trading Plan
# T                                                -
# V                                                -
# W                                                -
#
#                                              8
# Capital
# #                                            -
# A                      Administrative Expenses
# A                Asset-Backed Commercial Paper
# A                                            -
# B                                  Bridge Loan
# B                                            -
# C                    Certificated Secured Note
# C                       Class C Coverage Tests
# C                              Class E-R Notes
# C                     Collateral Administrator
# C                            Controlling Class
# C                            Custodial Account
# C                                            -
# D                                    Domiciled
# D                                            -
# U                                            -
# E                             Event of Default
# E                                            -
# F                        Fixed Rate Obligation
# F                                            -
# G                                            -
# H                                            -
# I                      Interest Accrual Period
# I                      Internal Rate of Return
# I                                            -
# J                                            -
# K                                            -
# L                                            -
# M                      Memorandum and Articles
# M              Moody’s Industry Classification
# M                  Moody’s Senior Secured Loan
# N                                            -
# O                          Optional Redemption
# O                                            -
# P                Permitted Deferrable Security
# P          Principal Financed Accrued Interest
# P                                            -
# Q                                            -
# R                                  Refinancing
# R                Registered Investment Adviser
# R         Required Overcollateralization Ratio
# R                                   Rule 17g-5
# S                                         Sale
# S                          Secured Obligations
# S            Senior Secured Floating Rate Note
# S        Subordinated Collateral Servicing Fee
# S                                            -
# T                          Trading Plan Period
# T                                            -
# V                                            -
# W                                            -

# %% [markdown]
# # Search in SQL database

# %% [markdown]
# Search information in the pre-created SQL database

# %%
def sql_search(indenture, term):
    sqlite_file = 'database.sqlite'
    conn = sqlite3.connect(sqlite_file)
    c = conn.cursor()
    
    query1 = """
    SELECT definition
    FROM DEFINITION
    WHERE term = '%s' AND file_name = '%s' 
    """ %(term, indenture)
    c.execute(query1)
    target_text = c.fetchall()
    
    query2 = """
    SELECT file_name, definition
    FROM DEFINITION
    WHERE term = '%s' AND file_name != '%s' 
    """ %(term, indenture)
    c.execute(query2)
    all_info = c.fetchall()
    text_list = [x[1] for x in all_info]
    
    return target_text[0][0], text_list, all_info

# %%
term = input()
target_text, text_list, all_info = sql_search(indenture_name, term)
# Out:
# Qualified Purchaser

# %%
#text_list

# %% [markdown]
# # Similarity Table

# %% [markdown]
# Calculate similarity score by self-trained word vector with 100 dimensions and Word Mover's Distance algorithm

# %%
from Similarity import Similarity_score
import matplotlib.pyplot as plt

# %%
search_indenture = indenture_name
search_term = 'Volcker Rule'
target_text, text_list, all_info = sql_search(search_indenture, search_term)
model_path = './w2v_selftrained/w2v_100_sg.bin'

# %%
score = Similarity_score(target_text, text_list, './w2v_selftrained/w2v_100_sg.bin')
final_score = score.result()
# final_score

# %%
similarity_table = pd.concat([pd.DataFrame(all_info, columns=['Indentures', 'Term Text']), 
                              pd.DataFrame(final_score, columns=['Similarity Score'])], axis=1) 
similarity_table = similarity_table.sort_values(by=['Similarity Score'], ascending=False)
temp_df = pd.DataFrame([search_indenture, target_text, '-'], 
                       index=['Indentures', 'Term Text','Similarity Score']).T
similarity_table = pd.concat([temp_df,similarity_table])

# %%
similarity_table 
# 0 is the searched indenture
# Out:
#                                                                                      Indentures  \
# 0     TEL133.20170810.dce07916-3ca5-2704-db92-fcfd7bbd6f53.5d35d0d4f9a56c3750c8880591dcb580.pdf
# 5     ALM6_1.20180611.b0eca308-20af-5a81-5bc5-a16f4bca5d7a.c6a25c15a03a42853fe1bc0eac9b00b3.pdf
# 15  STECR182.20180828.5e27ce4a-a011-1ffe-7711-1dd46c7729f0.a17f7cba4ba1ed0ef3c08d0af5245660.pdf
